# %%
import numpy as np
import pandas as pd
import copy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
train_df = pd.read_excel("训练.xlsx")
test1_df = pd.read_excel("测试A.xlsx")
test2_df = pd.read_excel("测试B.xlsx")

# %%
test1_ANS = pd.read_csv('TESTA_ANS.csv', header=None)

# %%
new_column = test1_df.columns

# %%
train_y = train_df[train_df.columns[-1]]
print(train_y.shape)
test1_y = test1_ANS[test1_ANS.columns[-1]]
print(test1_y.shape)
# Out:
# (500,)
# (100,)

# %%
train_df = train_df[new_column]

# %%
train_id = train_df['ID']
test1_id = test1_df['ID']
test2_id = test2_df['ID']
train_df.drop(['ID'], axis=1, inplace=True)
test1_df.drop(['ID'], axis=1, inplace=True)
test2_df.drop(['ID'], axis=1, inplace=True)

# %%
names = train_df.columns
dts = train_df.dtypes
drop_names = []
year = []
ratio = 0.1
for i in range(len(names)):
    n = names[i]
    tp = dts[i]
    trd = train_df[n]
    ted = test1_df[n]
    if 'object' == str(tp):
        continue
    else:
        misstr = np.sum(trd.isnull())/500
        misste = np.sum(ted.isnull())/100
        if np.abs(misstr-misste) > ratio:
            drop_names.append(n)
        else:
            if 'int' in str(tp):
                if str(train_df[n][0])[:4] == '2017' and str(train_df[n][499])[:4] == '2017':
                    year.append(n)
            else:
                trrd = trd[trd.notnull()]
                terd = ted[ted.notnull()]
                m1 = np.mean(trrd)
                s1 = np.std(trrd)
                m2 = np.mean(terd)
                s2 = np.std(terd)
                if np.abs(m1-m2)>ratio*np.abs(m1) and np.abs(s1-s2)>ratio*np.abs(s1):
                    drop_names.append(n)
print(len(drop_names))
print(len(year))
# Out:
# 855
# 78

# %%
# Out:
#              210X24         210X204         210X205            220X71  \
# 0    20170725030628  20170725031229  20170725030712  2017072611214726
# 1    20170725030849  20170725031537  20170725031021  2017072611203201
# 2    20170725031113  20170725031807  20170725031250  2017072611191653
# 3    20170723105612  20170723110319  20170723105803  2017072502090981
# 4    20170723111008  20170723111759  20170723111243  2017072502044293
# 5    20170723115220  20170723120156  20170723115640  2017072501510239
# 6    20170723121001  20170723121652  20170723121136  2017072501422837
# 7    20170723093642  20170723094341  20170723093825  2017072421135804
# 8    20170723094350  20170723095105  20170723094549  2017072421101384
# 9    20170723095328  20170723100201  20170723095646  2017072421041285
# 10   20170723100315  20170723101124  20170723100608  2017072420590387
# 11   20170723221241  20170723221828  20170723221311  2017072411302765
# ...

# %%
str(train_df['210X24'][0])[:4]=='2017'
# Out:
# True

# %%
train_df.drop(drop_names, axis=1, inplace=True)
test1_df.drop(drop_names, axis=1, inplace=True)
test2_df.drop(drop_names, axis=1, inplace=True)

# %%
train_df.shape
# Out:
# (500, 7172)

# %%
names = train_df.columns
dfs = train_df.dtypes

# %%
# ints or strings
ints = []
for i in range(len(names)):
    if 'int' in str(dfs[i]) or 'object' in str(dfs[i]):
        ints.append(names[i])
print(len(ints))
# Out:
# 1749

# %%
df_X = pd.concat([train_df, test1_df, test2_df], axis=0)

# %%
dfx_year = df_X[year]

# %%
remains1 = []
remains2 = []
tobedrop = []

for n in ints:
    lu1 = len(train_df[n].unique())
    lu2 = len(df_X[n].unique())
    if lu1 < 10 and lu1 > 1:
        remains1.append(n)
    if lu2 < 10 and lu2 > 1:
        remains2.append(n)
    if lu1 != lu2:
        tobedrop.append(n)
    
print(len(remains1), len(remains2), len(tobedrop), len(year))
# Out:
# 405 473 766 78

# %%
toberemain = list(set(remains1) & set(remains2) - set(tobedrop))
print(len(toberemain))
# Out:
# 294

# %%
def dict2list(dic:dict):
    ''' 将字典转化为列表 '''
    keys = dic.keys()
    vals = dic.values()
    lst = [(key, val) for key, val in zip(keys, vals)]
    return lst

def LastRemainJudge(column):
    unique = set(column)
    uf = {}
    for u in unique:
        uf[u] = 0
    for c in column:
        uf[c] += 1
    sl = sorted(dict2list(uf), key = lambda x:x[1], reverse=True)
    x = sl[0][1]/len(column)
    sl = np.array(sl)
    if x < 0.8:
        #print(sl[:, 1]/len(column))
        return True
    else:
        return False

# %%
lm1 = []
lm2 = []
for n in toberemain:
    if LastRemainJudge(train_df[n]):
        lm1.append(n)
    if LastRemainJudge(df_X[n]):
        lm2.append(n)
print(len(lm1), len(lm2), len(set(lm1)&set(lm2)))
# Out:
# 185 189 183

# %%
names = df_X.columns
dts = df_X.dtypes
dfx_float_n = []
dfx_onehot_n = list(set(lm1) & set(lm2))
print(len(dfx_onehot_n))
for i in range(len(names)):
    n = names[i]
    d = dts[i]
    if 'float' in str(d):
        dfx_float_n.append(n)
print(len(dfx_float_n))
dfx_float = df_X[dfx_float_n]
dfx_onehot = df_X[dfx_onehot_n]
print(dfx_float.shape, dfx_onehot.shape)
# Out:
# 183
# 5628
# (721, 5628) (721, 183)

# %%
drop_names = []
names = dfx_float.columns
for n in names:
    x = np.sum(dfx_float[n].isnull())
    if x > 300:
        drop_names.append(n)
print(len(drop_names))
# Out:
# 64

# %%
dfx_float.drop(drop_names, axis=1, inplace=True)
# Out:
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
means = []
stds = []
drop_names = []
names = dfx_float.columns
for n in names:
    c = dfx_float[n]
    r = c[c.notnull()]
    tmpm = np.mean(r)
    tmps = np.std(r)
    means.append(tmpm)
    stds.append(tmps)
    if tmps == 0:
        drop_names.append(n)
print(len(set(means)), len(set(stds)))
print(len(drop_names))
# Out:
# 2149 2149
# 0

# %%
# not move sames first, fill nan
added = set()
sames = []
for i in range(len(names)):
    tmpsl = []
    tmpsl.append(i)
    for j in range(i+1, len(names)):
        if means[i] == means[j] and stds[i] == stds[j]:
            if i not in added:
                added.add(i)
            if j not in added:
                added.add(j)
                tmpsl.append(j)
    if len(tmpsl) > 1:
        sames.append(tmpsl)
print(len(sames))
# Out:
# 701

# %%
names = dfx_float.columns
drop_names = []
for i in sames:
    for j in i[1:]:
        drop_names.append(names[j])
print(len(drop_names))
# Out:
# 3148

# %%
print(dfx_float.shape)
# Out:
# (721, 5298)

# %%
import copy
trainx_float = copy.copy(dfx_float)
trainx_float.drop(drop_names, axis=1, inplace=True)
print(trainx_float.shape)
# Out:
# (721, 2150)

# %%
names = trainx_float.columns
for n in names:
    c = trainx_float[n]
    r = c[c.notnull()]
    tmpm = np.mean(r)
    tmps = np.std(r)
    assert tmps>0
    trainx_float[n][c.isnull()] = tmpm
print(np.sum(trainx_float.isnull().values))
# Out:
# 0

# %%
# it shall be that there is only thre lines with nan in log1p
mid = trainx_float-np.min(trainx_float)+1
trainx_log1p = np.log1p(mid)
del mid
print(np.sum(trainx_log1p.isnull().values))
# Out:
# 0

# %%
for n in names:
    m1 = np.mean(trainx_float[n])
    s1 = np.std(trainx_float[n])
    assert s1 > 0
    trainx_float[n] = (trainx_float[n]-m1)/s1
    m2 = np.mean(trainx_log1p[n])
    s2 = np.std(trainx_log1p[n])
    assert s2 > 0
    trainx_log1p[n] = (trainx_log1p[n]-m2)/s2

# %%
# make onehots onehot
ohnames = dfx_onehot.columns
for i in range(len(ohnames)):
    n = ohnames[i]
    tmp = pd.get_dummies(dfx_onehot[n], prefix='onehot_'+str(i))
    dfx_onehot = pd.concat([dfx_onehot, tmp], axis=1)
    print(dfx_onehot.shape)
# Out:
# (721, 186)
# (721, 195)
# (721, 198)
# (721, 205)
# (721, 207)
# (721, 209)
# (721, 215)
# (721, 218)
# (721, 223)
# (721, 225)
# (721, 230)
# (721, 239)
# (721, 241)
# (721, 244)
# (721, 253)
# (721, 256)
# (721, 259)
# (721, 265)
# (721, 270)
# (721, 276)
# (721, 281)
# (721, 283)
# (721, 287)
# (721, 294)
# (721, 301)
# (721, 309)
# (721, 312)
# (721, 316)
# (721, 324)
# (721, 332)
# (721, 334)
# (721, 339)
# (721, 348)
# (721, 350)
# (721, 352)
# (721, 354)
# (721, 360)
# (721, 363)
# (721, 365)
# (721, 367)
# (721, 374)
# (721, 377)
# (721, 383)
# (721, 385)
# (721, 394)
# (721, 403)
# (721, 405)
# (721, 407)
# (721, 410)
# (721, 412)
# (721, 414)
# (721, 422)
# (721, 424)
# (721, 426)
# (721, 435)
# (721, 439)
# (721, 441)
# (721, 443)
# (721, 446)
# (721, 449)
# (721, 453)
# (721, 459)
# (721, 461)
# (721, 463)
# (721, 468)
# (721, 475)
# (721, 480)
# (721, 487)
# (721, 490)
# (721, 493)
# (721, 499)
# (721, 501)
# (721, 504)
# (721, 508)
# (721, 510)
# (721, 513)
# ...

# %%
dfx_onehot.drop(ohnames, axis=1, inplace=True)
print(dfx_onehot.shape)
# Out:
# (721, 791)

# %%
dfx_float = trainx_float
dfx_log1p = trainx_log1p

# %%
year_n = dfx_year.columns
standardlen = len(str(dfx_year[year_n[0]][0]))
for i in range(1, len(year_n)):
    l = len(str(dfx_year[year_n[i]][0]))
    bias = standardlen - l
    if l > 0:
        for j in range(l):
            dfx_year[year_n[i]] /= 10
    elif l < 0:
        for j in range(-l):
            dfx_year[year_n[i]] *= 10
    dfx_year[year_n[i]] = dfx_year[year_n[i]] + dfx_year[year_n[0]]
# Out:
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
for i in range(1, len(year_n)):
    dfx_year[year_n[i]] = dfx_year[year_n[i]] - 2 * dfx_year[year_n[0]]
# Out:
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfx_time = (dfx_year - np.mean(dfx_year))/np.std(dfx_year)

# %%
dfx_time
# Out:
#        210X24   210X204   210X205    220X71    220X79    220X87    220X95  \
# 0   -0.027748  0.027748  0.027748  0.027748  0.027748  0.027748  0.027748
# 1   -0.027747  0.027747  0.027747  0.027747  0.027747  0.027747  0.027747
# 2   -0.027747  0.027747  0.027747  0.027747  0.027747  0.027747  0.027747
# 3   -0.032822  0.032822  0.032822  0.032822  0.032822  0.032822  0.032822
# 4   -0.032807  0.032807  0.032807  0.032807  0.032807  0.032807  0.032807
# 5   -0.032796  0.032796  0.032796  0.032796  0.032796  0.032796  0.032796
# 6   -0.032781  0.032781  0.032781  0.032781  0.032781  0.032781  0.032781
# 7   -0.032853  0.032853  0.032853  0.032853  0.032853  0.032853  0.032853
# 8   -0.032851  0.032851  0.032851  0.032851  0.032851  0.032851  0.032851
# 9   -0.032849  0.032849  0.032849  0.032849  0.032849  0.032849  0.032849
# 10  -0.032835  0.032835  0.032835  0.032835  0.032835  0.032835  0.032835
# 11  -0.032517  0.032517  0.032517  0.032517  0.032517  0.032517  0.032517
# ...

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
# Out:
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def MSE(y_raw, y_pred):
    print(np.mean(np.square(y_raw-y_pred)))

# %%
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
# Out:
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
from sklearn.model_selection import KFold 
kf = KFold(n_splits=5, random_state=2018)
def get_oof(rgr, xtrain, ytrain, xtest, lenot):
    oof_train = np.zeros((lenot,))
    oof_test = np.zeros((100,))
    oof_test_skf = np.empty((5, 100))
    for i, (train_index, test_index) in enumerate(kf.split(xtrain)):
        kf_xtrain = xtrain[train_index]
        kf_ytrain = ytrain[train_index]
        kf_xtest = xtrain[test_index]
        rgr.fit(kf_xtrain, kf_ytrain)
        oof_train[test_index] = rgr.predict(kf_xtest)
        oof_test_skf[i, : ] = rgr.predict(xtest)
    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1,1), oof_test.reshape(-1,1)

# %%
dfx = pd.concat([dfx_log1p, dfx_onehot], axis=1)
dfx.shape
# Out:
# (721, 2941)

# %%
ndfx = pd.concat([dfx, dfx_time], axis=1)
ndfx.shape
# Out:
# (721, 3019)

# %%
# for abs(m1-m2)>ratio*m1
xgb = XGBRegressor(gamma=0.0004, max_depth=3, objective='reg:gamma', subsample=0.8)
xgb.fit(dfx[:500], train_y)
tr_pred = xgb.predict(dfx[:500])
te_pred = xgb.predict(dfx[500:600])
MSE(tr_pred, train_y.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.00473646183736
# 0.0400896951839

# %%
xgb = XGBRegressor(gamma=0.0004, max_depth=3, objective='reg:gamma', subsample=0.8)
xgb.fit(ndfx[:500].values, train_y.values)
tr_pred = xgb.predict(ndfx[:500].values)
te_pred = xgb.predict(ndfx[500:600].values)
MSE(tr_pred, train_y.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.00536375523317
# 0.0392030344683

# %%
test2_pred = xgb.predict(ndfx[-121:].values)
test2_pred = test2_pred.reshape(121)
save = pd.DataFrame({'ID':test2_id, 'value':test2_pred})
save.to_csv('answerB_Synchronous_logoh_xgb_20180115.csv', index=False, header=False)

# %%
xgb = XGBRegressor(gamma=0.001, max_depth=3, objective='reg:linear', subsample=0.7)
tr_pred, te_pred = get_oof(xgb, ndfx[:500].values, train_y.values, ndfx[500:600].values, 500)
MSE(tr_pred, train_y.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.050525749483
# 0.055876901552

# %%
# for abs(m1-m2)>ratio*m1 and drop y>3.4
xgb = XGBRegressor(gamma=0.00075, max_depth=3, objective='reg:gamma', subsample=0.69)
xgb.fit(nx, ny)
tr_pred = xgb.predict(nx)
te_pred = xgb.predict(dfx[500:600])
MSE(tr_pred, ny.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.00492197172483
# 0.0391660009687

# %%
test2_pred = xgb.predict(dfx[-121:])
test2_pred = test2_pred.reshape(121)
save = pd.DataFrame({'ID':test2_id, 'value':test2_pred})
save.to_csv('answerB_Synchronous_logoh_paramxgb_dropo34_20180115.csv', index=False, header=False)

# %%
# for abs(m1-m2)>ratio*m1 and drop y>3.4 and y<2.4
xgb = XGBRegressor(gamma=0.0001, max_depth=3, objective='reg:gamma', subsample=0.85)
xgb.fit(nx, ny)
tr_pred = xgb.predict(nx)
te_pred = xgb.predict(dfx[500:600])
MSE(tr_pred, ny.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.00445506309676
# 0.0430554549512

# %%
# for abs(m1-m2)>ratio * s1
xgb = XGBRegressor(gamma=0.0001, max_depth=3, objective='reg:gamma', subsample=0.85)
xgb.fit(dfx[:500], train_y)
tr_pred = xgb.predict(dfx[:500])
te_pred = xgb.predict(dfx[500:600])
MSE(tr_pred, train_y.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.00528926574392
# 0.0432010075581

# %%
test2_pred = xgb.predict(dfx[-121:])
test2_pred = test2_pred.reshape(121)
save = pd.DataFrame({'ID':test2_id, 'value':test2_pred})
save.to_csv('answerB_Synchronous_logoh_xgb_20180114.csv', index=False, header=False)

# %%
names = dfx_float.columns
for n in names:
    c = dfx_float[n]
    r = c[c.notnull()]
    tmpm = np.mean(r)
    tmps = np.std(r)
    assert tmps>0
    dfx_float[n][c.isnull()] = tmpm
print(np.sum(dfx_float.isnull().values))
# it shall be that there is only thre lines with nan in log1p
mid = dfx_float-np.min(dfx_float)+1
dfx_log1p = np.log1p(mid)
del mid
print(np.sum(dfx_log1p.isnull().values))
# Out:
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5088: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /home/magnusterra/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0
# 0

# %%
dfx_log1p.shape
# Out:
# (721, 5298)

# %%
xgb = XGBRegressor(gamma=0.0005, max_depth=3, objective='reg:gamma', subsample=0.85)
xgb.fit(dfx[:500], train_y)
tr_pred = xgb.predict(dfx[:500])
te_pred = xgb.predict(dfx[500:600])
MSE(tr_pred, train_y.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.00473748652785
# 0.0420919359219

# %%
dx = pd.concat([dfx_log1p, dfx_onehot], axis=1)
xgb = XGBRegressor(gamma=0.0001, max_depth=1, objective='reg:linear', subsample=0.7)
xgb.fit(dfx_log1p[:500], train_y)
tr_pred = xgb.predict(dfx_log1p[:500])
te_pred = xgb.predict(dfx_log1p[500:600])
MSE(tr_pred, train_y.values)
MSE(te_pred, test1_y.values)
# Out:
# 0.0218066446772
# 0.041974381569

# %%
test2_pred = xgb.predict(dfx_log1p[-121:])
test2_pred = test2_pred.reshape(121)
save = pd.DataFrame({'ID':test2_id, 'value':test2_pred})
save.to_csv('answerB_noSynchronous_log_xgb_20180114.csv', index=False, header=False)
